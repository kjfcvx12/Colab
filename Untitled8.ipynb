# %%
import numpy as np
import pandas as pd
import torch.nn as nn
import torch
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('C:/a/ai/data/insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#문자를 수로 변경 (원-핫 인코딩)
# 원-핫인코딩(yes일 때 true로 설정) 후 데이터타입 정수형으로 줌
df['target'] = pd.get_dummies(df['smoker'])['yes'].astype('int')
df
# Out:
#       age     sex     bmi  children smoker     region      charges  target
# 0      19  female  27.900         0    yes  southwest  16884.92400       1
# 1      18    male  33.770         1     no  southeast   1725.55230       0
# 2      28    male  33.000         3     no  southeast   4449.46200       0
# 3      33    male  22.705         0     no  northwest  21984.47061       0
# 4      32    male  28.880         0     no  northwest   3866.85520       0
# ...   ...     ...     ...       ...    ...        ...          ...     ...
# 1333   50    male  30.970         3     no  northwest  10600.54830       0
# 1334   18  female  31.920         0     no  northeast   2205.98080       0
# 1335   18  female  36.850         0     no  southeast   1629.83350       0
# 1336   21  female  25.800         0     no  southwest   2007.94500       0
# 1337   61  female  29.070         0    yes  northwest  29141.36030       1
#
# [1338 rows x 8 columns]

# %%
#smoker열 삭제
df.drop('smoker', axis=1, inplace=True)
df
# Out:
#       age     sex     bmi  children     region      charges  target
# 0      19  female  27.900         0  southwest  16884.92400       1
# 1      18    male  33.770         1  southeast   1725.55230       0
# 2      28    male  33.000         3  southeast   4449.46200       0
# 3      33    male  22.705         0  northwest  21984.47061       0
# 4      32    male  28.880         0  northwest   3866.85520       0
# ...   ...     ...     ...       ...        ...          ...     ...
# 1333   50    male  30.970         3  northwest  10600.54830       0
# 1334   18  female  31.920         0  northeast   2205.98080       0
# 1335   18  female  36.850         0  southeast   1629.83350       0
# 1336   21  female  25.800         0  southwest   2007.94500       0
# 1337   61  female  29.070         0  northwest  29141.36030       1
#
# [1338 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

features=df.iloc[:, 0:6]
label=df['target']

# %%
X_train, X_test, y_train, y_test=train_test_split(features, label, test_size=0.2, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1070, 6) (268, 6) (1070,) (268,)

# %%
#범주형 데이터를 원핫인코딩을 사용해 0,1(불린값으로 변환)
X_train_encode=pd.get_dummies(X_train)
X_test_encode=pd.get_dummies(X_test)

# %%
#train에 있는 열이 test에 없을 수 있기 때문에 컬럼 순서를 train과 동일하게 맞추고 , 없는 열은 0으로 다 채움
X_test_encode = X_test_encode.reindex(columns=X_train_encode.columns, fill_value=0)

# %%
X_test_encode
# Out:
#       age     bmi  children      charges  sex_female  sex_male  \
# 559    19  35.530         0   1646.42970       False      True
# 1087   57  31.540         0  11353.22760       False      True
# 1020   51  37.000         0   8798.59300       False      True
# 460    49  36.630         3  10381.47870        True     False
# 802    21  22.300         1   2103.08000       False      True
# ...   ...     ...       ...          ...         ...       ...
# 682    39  35.300         2  40103.89000       False      True
# 629    44  38.950         0  42983.45850        True     False
# 893    47  38.940         2  44202.65360       False      True
# 807    19  36.575         0   2136.88225        True     False
# 1165   35  26.125         0   5227.98875        True     False
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# 559              False              True             False             False
# 1087             False              True             False             False
# 1020             False             False             False              True
# 460              False             False              True             False
# 802              False             False             False              True
# ...                ...               ...               ...               ...
# 682              False             False             False              True
# 629              False              True             False             False
# 893              False             False              True             False
# 807              False              True             False             False
# 1165              True             False             False             False
#
# [268 rows x 10 columns]

# %%
#스케일링
sc=StandardScaler()
X_train_encode = sc.fit_transform(X_train_encode)
X_test_encode = sc.transform(X_test_encode)

# %%
#넘파이배열=> 파이토치 텐서로 변환
#X_train_tensor=torch.FloatTensor(sc.fit_transform(X_train_encode))
X_train_tensor=torch.from_numpy(X_train_encode).float()
X_test_tensor=torch.from_numpy(X_test_encode).float()
print(X_train_tensor.shape, X_test_tensor.shape)
# Out:
# torch.Size([1070, 10]) torch.Size([268, 10])

# %%
#테스트용도 텐서로 변환 -> 신경망 입력과 맞춘다(N,1) -> 차원추가
y_train_tensor=torch.from_numpy(y_train.values).float().unsqueeze(1)
y_test_tensor=torch.from_numpy(y_test.values).float().unsqueeze(1)
print(y_train_tensor.shape, y_test_tensor.shape)
# Out:
# torch.Size([1070, 1]) torch.Size([268, 1])

# %%
#입력층 => input_dim 차원의 feature
#은닉층 => 256,128,32,8
#출력증 => output_dim 차원의 예측값 
#다층 퍼셉트론(MLP)
class SmokeModel(nn.Module):
    def __init__(self, input_dim, output_dim):
        super().__init__()
        self.linear=nn.Sequential(
            nn.Linear(input_dim, 200),
            #음수영역에도 작은 기울기를 주면서 죽은 신호 완화시킴
            nn.LeakyReLU(0.1), 
            nn.Linear(200, 100),
            nn.LeakyReLU(0.1),
            nn.Linear(100, 20),
            nn.LeakyReLU(0.1),
            nn.Linear(20, 5),
            nn.LeakyReLU(0.1),
            nn.Linear(5, output_dim), #점점 입력차원수를 줄여가면서 차원 축소함
            nn.Sigmoid() #이진 분류 시 필수 메소드
        )
    #모델이 입력받으면 forward가 호출된다
    def forward(self, x):
        y=self.linear(x)
        return y

# %%
input_dim = X_train_tensor.shape[1]
output_dim = y_train_tensor.shape[1]

# %%
model=SmokeModel(input_dim, output_dim)

# %%
#손실함수 정의
bceloss=nn.BCELoss()
optimizer=torch.optim.Adam(model.parameters(), lr=0.001)
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )

# %%
from torch.utils.data import TensorDataset, DataLoader

train_dataset=TensorDataset(X_train_tensor, y_train_tensor)
train_loader=DataLoader(train_dataset, batch_size=250, shuffle=True)

loss1=[]

for epoch in range(100):
    for x,y in train_loader:
        y_pred=model(x)
        loss=bceloss(y_pred,y)
        loss1.append(loss)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    print(sum(loss1) / len(loss1))
# Out:
# tensor(0.6716, grad_fn=<DivBackward0>)
# tensor(0.6687, grad_fn=<DivBackward0>)
# tensor(0.6646, grad_fn=<DivBackward0>)
# tensor(0.6591, grad_fn=<DivBackward0>)
# tensor(0.6525, grad_fn=<DivBackward0>)
# tensor(0.6436, grad_fn=<DivBackward0>)
# tensor(0.6328, grad_fn=<DivBackward0>)
# tensor(0.6200, grad_fn=<DivBackward0>)
# tensor(0.6047, grad_fn=<DivBackward0>)
# tensor(0.5854, grad_fn=<DivBackward0>)
# tensor(0.5612, grad_fn=<DivBackward0>)
# tensor(0.5340, grad_fn=<DivBackward0>)
# tensor(0.5063, grad_fn=<DivBackward0>)
# tensor(0.4797, grad_fn=<DivBackward0>)
# tensor(0.4559, grad_fn=<DivBackward0>)
# tensor(0.4339, grad_fn=<DivBackward0>)
# tensor(0.4141, grad_fn=<DivBackward0>)
# tensor(0.3970, grad_fn=<DivBackward0>)
# tensor(0.3817, grad_fn=<DivBackward0>)
# tensor(0.3687, grad_fn=<DivBackward0>)
# tensor(0.3560, grad_fn=<DivBackward0>)
# tensor(0.3442, grad_fn=<DivBackward0>)
# tensor(0.3334, grad_fn=<DivBackward0>)
# tensor(0.3231, grad_fn=<DivBackward0>)
# tensor(0.3146, grad_fn=<DivBackward0>)
# tensor(0.3061, grad_fn=<DivBackward0>)
# tensor(0.2979, grad_fn=<DivBackward0>)
# tensor(0.2906, grad_fn=<DivBackward0>)
# tensor(0.2840, grad_fn=<DivBackward0>)
# tensor(0.2774, grad_fn=<DivBackward0>)
# tensor(0.2717, grad_fn=<DivBackward0>)
# tensor(0.2658, grad_fn=<DivBackward0>)
# tensor(0.2603, grad_fn=<DivBackward0>)
# tensor(0.2553, grad_fn=<DivBackward0>)
# tensor(0.2505, grad_fn=<DivBackward0>)
# tensor(0.2457, grad_fn=<DivBackward0>)
# tensor(0.2414, grad_fn=<DivBackward0>)
# tensor(0.2375, grad_fn=<DivBackward0>)
# tensor(0.2334, grad_fn=<DivBackward0>)
# tensor(0.2295, grad_fn=<DivBackward0>)
# tensor(0.2257, grad_fn=<DivBackward0>)
# tensor(0.2226, grad_fn=<DivBackward0>)
# tensor(0.2194, grad_fn=<DivBackward0>)
# tensor(0.2167, grad_fn=<DivBackward0>)
# tensor(0.2135, grad_fn=<DivBackward0>)
# tensor(0.2108, grad_fn=<DivBackward0>)
# tensor(0.2080, grad_fn=<DivBackward0>)
# tensor(0.2054, grad_fn=<DivBackward0>)
# tensor(0.2027, grad_fn=<DivBackward0>)
# tensor(0.2002, grad_fn=<DivBackward0>)
# tensor(0.1976, grad_fn=<DivBackward0>)
# tensor(0.1954, grad_fn=<DivBackward0>)
# tensor(0.1931, grad_fn=<DivBackward0>)
# tensor(0.1907, grad_fn=<DivBackward0>)
# tensor(0.1889, grad_fn=<DivBackward0>)
# tensor(0.1868, grad_fn=<DivBackward0>)
# tensor(0.1847, grad_fn=<DivBackward0>)
# tensor(0.1829, grad_fn=<DivBackward0>)
# tensor(0.1810, grad_fn=<DivBackward0>)
# tensor(0.1791, grad_fn=<DivBackward0>)
# tensor(0.1774, grad_fn=<DivBackward0>)
# tensor(0.1757, grad_fn=<DivBackward0>)
# tensor(0.1740, grad_fn=<DivBackward0>)
# tensor(0.1724, grad_fn=<DivBackward0>)
# tensor(0.1708, grad_fn=<DivBackward0>)
# tensor(0.1692, grad_fn=<DivBackward0>)
# tensor(0.1677, grad_fn=<DivBackward0>)
# tensor(0.1661, grad_fn=<DivBackward0>)
# tensor(0.1646, grad_fn=<DivBackward0>)
# tensor(0.1632, grad_fn=<DivBackward0>)
# tensor(0.1619, grad_fn=<DivBackward0>)
# tensor(0.1605, grad_fn=<DivBackward0>)
# tensor(0.1591, grad_fn=<DivBackward0>)
# tensor(0.1577, grad_fn=<DivBackward0>)
# tensor(0.1564, grad_fn=<DivBackward0>)
# tensor(0.1553, grad_fn=<DivBackward0>)
# tensor(0.1540, grad_fn=<DivBackward0>)
# tensor(0.1528, grad_fn=<DivBackward0>)
# tensor(0.1516, grad_fn=<DivBackward0>)
# tensor(0.1504, grad_fn=<DivBackward0>)
# tensor(0.1494, grad_fn=<DivBackward0>)
# tensor(0.1482, grad_fn=<DivBackward0>)
# tensor(0.1471, grad_fn=<DivBackward0>)
# tensor(0.1460, grad_fn=<DivBackward0>)
# tensor(0.1450, grad_fn=<DivBackward0>)
# tensor(0.1439, grad_fn=<DivBackward0>)
# tensor(0.1428, grad_fn=<DivBackward0>)
# tensor(0.1418, grad_fn=<DivBackward0>)
# tensor(0.1407, grad_fn=<DivBackward0>)
# tensor(0.1396, grad_fn=<DivBackward0>)
# tensor(0.1386, grad_fn=<DivBackward0>)
# tensor(0.1376, grad_fn=<DivBackward0>)
# tensor(0.1366, grad_fn=<DivBackward0>)
# tensor(0.1356, grad_fn=<DivBackward0>)
# tensor(0.1346, grad_fn=<DivBackward0>)
# tensor(0.1336, grad_fn=<DivBackward0>)
# tensor(0.1327, grad_fn=<DivBackward0>)
# tensor(0.1318, grad_fn=<DivBackward0>)
# tensor(0.1309, grad_fn=<DivBackward0>)
# tensor(0.1300, grad_fn=<DivBackward0>)

# %%
total=0
correct=0

#model.eval()
#역전파 비활성화 =>  Gradient 계산 끄기(메모리 절약)
with torch.no_grad():
    for x,y in train_loader:
        outputs=model(x)
        predict=(outputs > 0.5).float() #이진 예측
        total+=y.size(0)
        correct+=(predict==y).sum().item()
        print(y.size(0))

accuracy=correct/total
print(sum(loss1)/len(loss1))
print(accuracy)
#정확도 100% 이고, 손실은 0.0446 => 확신 아직 100%로는 아닌상태
# Out:
# 250
# 250
# 250
# 250
# 70
# tensor(0.1300, grad_fn=<DivBackward0>)
# 0.9850467289719627

# %%
model
# Out:
# SmokeModel(
#   (linear): Sequential(
#     (0): Linear(in_features=10, out_features=200, bias=True)
#     (1): LeakyReLU(negative_slope=0.1)
#     (2): Linear(in_features=200, out_features=100, bias=True)
#     (3): LeakyReLU(negative_slope=0.1)
#     (4): Linear(in_features=100, out_features=20, bias=True)
#     (5): LeakyReLU(negative_slope=0.1)
#     (6): Linear(in_features=20, out_features=5, bias=True)
#     (7): LeakyReLU(negative_slope=0.1)
#     (8): Linear(in_features=5, out_features=1, bias=True)
#     (9): Sigmoid()
#   )
# )

# %%
print(X_test_tensor.shape, y_test_tensor.shape)
# Out:
# torch.Size([268, 10]) torch.Size([268, 1])

# %%
#테스트용 데이터셋
from torch.utils.data import TensorDataset, DataLoader

test_dataset=TensorDataset(X_test_tensor, y_test_tensor)
test_loader=DataLoader(test_dataset, batch_size=250, shuffle=False)

#append -> 
y_pred=[]
model.eval()
with torch.no_grad():
    for x,_ in test_loader:
        y_test_pred=model(x)
        y_test_pred_sigmoid = torch.round(y_test_pred)
        y_pred.extend(y_test_pred_sigmoid)
print(y_pred)
y_pred_tensor=torch.tensor(y_pred)
# Out:
# [tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([0.]), tensor([0.]), tensor([0.]), tensor([1.]), tensor([1.]), tensor([1.]), tensor([0.]), tensor([0.])]

# %%
y_pred_tensor.shape, y_test_tensor.shape
# Out:
# (torch.Size([268]), torch.Size([268, 1]))

# %%
from sklearn.metrics import f1_score, precision_score

# %%
#텐서-> 넘파이로 바꿔서 성능평가
y_numpy_test=y_test_tensor.numpy()
y_numpy_pred=y_pred_tensor.numpy()

# %%
# 중복원소 제거하고 고유한 값 확인
#이진분류 -> 정상적인 분류로 예측함
torch.unique(y_pred_tensor)
# Out:
# tensor([0., 1.])

# %%
torch.unique(y_test_tensor)
# Out:
# tensor([0., 1.])

# %%
torch.unique(y_pred_tensor, return_counts=True)
# Out:
# (tensor([0., 1.]), tensor([212,  56]))

# %%
torch.unique(y_test_tensor, return_counts=True)
# Out:
# (tensor([0., 1.]), tensor([214,  54]))
