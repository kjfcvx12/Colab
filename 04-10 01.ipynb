# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("C:/a/run/train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#age, cabin, embarked 결측치 개수 확인
df[['Age','Cabin','Embarked']].isna().sum()
# Out:
# Age           0
# Cabin       687
# Embarked      0
# dtype: int64

# %%
# age결측치 - age의 평균으로 채운다
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
# embarked 결측지 - 제일 자주 나온 값으로 채운다
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])
df['Embarked'].isna().sum()
# Out:
# np.int64(0)

# %%
# pclass=1 이면서 age>30 인 사람만 선택
(df['Pclass']==1)&(df['Age']>30)
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
# df[(df['Pclass']==1)&(df['Age']>30)]
# 간단한 행 필터링 또는 열 선택
# 조건문과 함께 특정 열만 뽑는 것이 불가능
df.loc[(df['Pclass']==1)&(df['Age']>30)]
# 행과 열을 동시에 지정하는 복합 선택
# df.loc[조건, '열이름']으로 특정 열만 추출 가능
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# ..           ...       ...     ...
# 862          863         1       1
# 867          868         0       1
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# AgeGroup 열 새로 생성
df['AgeGroup']=df['Age'].apply(lambda x: 'Adult' if x>=19 else 'Child')
df

# def age_group(age):
#     if age>=19:
#         return "Adult"
#     else:
#         return "Child"

# df['AgeGroup']=df['Agd'].apply(age_group)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
# pclass 별 age 평균, fare 평균, Survived 합계 계산
group1=df.groupby(['Pclass']).agg({
    'Age':'mean',
    'Fare':'mean',
    'Survived':'sum'
})
group1
# Out:
#               Age       Fare  Survived
# Pclass
# 1       37.048118  84.154687       136
# 2       29.866958  20.662183        87
# 3       26.403259  13.675550       119

# %%
# cabin에 b42가 있는지 확인
df['Cabin'].isin(['B42'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889    False
# 890    False
# Name: Cabin, Length: 891, dtype: bool

# %%
# fare가 가장 높은 사람 상위 5명
#top_fare=df.sort_values(by=['Fare','Age'], ascending=[False,False]).head(5)
top_fare=df.sort_values('Fare', ascending=False).head(5)
top_fare
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 438          439         0       1                   Fortune, Mr. Mark
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
#
#     AgeGroup FareCut
# 679    Adult       4
# 258    Adult       4
# 737    Adult       4
# ...

# %%
# 나이 그룹화= 평균 fare
avg_age=df.groupby('Age')['Fare'].mean()
avg_age
# Out:
# Age
# 0.42       8.5167
# 0.67      14.5000
# 0.75      19.2583
# 0.83      23.8750
# 0.92     151.5500
#            ...
# 70.00     40.7500
# 70.50      7.7500
# 71.00     42.0792
# 74.00      7.7750
# 80.00     30.0000
# Name: Fare, Length: 89, dtype: float64

# %%
# age>=30 이면서 fare가 100 이상인 사람들
titanic=df.loc[(df['Age']>=30)&(df['Fare']>=100)]
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 195          196         1       1
# 215          216         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 299          300         1       1
# 318          319         1       1
# 319          320         1       1
# 325          326         1       1
# 332          333         0       1
# 337          338         1       1
# 380          381         1       1
# 390          391         1       1
# 438          439         0       1
# 537          538         1       1
# 544          545         0       1
# 581          582         1       1
# 609          610         1       1
# 659          660         0       1
# 660          661         1       1
# 679          680         1       1
# 698          699         0       1
# 716          717         1       1
# 737          738         1       1
# 763          764         1       1
# ...

# %%
# age가 많은 사람 5명
df_sort=df.sort_values('Age', ascending=False).head(5)
df_sort
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked AgeGroup  \
# 630  male  80.0      0      0     27042  30.0000   A23        S    Adult
# 851  male  74.0      0      0    347060   7.7750   NaN        S    Adult
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C    Adult
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C    Adult
# 116  male  70.5      0      0    370369   7.7500   NaN        Q    Adult
#
#     FareCut
# 630       1
# 851       1
# 96        1
# 493       1
# 116       1

# %%
# cut(범주화)
# 자동으로 최소값, 회대값 사이를 동일한 간격으로 4등분
df['FareCut']=pd.cut(df['Fare'], bins=4, labels=[1,2,3,4])
# df['FareCut'].tail(50)

# %%
# correlataion coefficient (수치형 컬럼들 간의 상관계수)
# 숫자로 된 컬럼만 자동으로 골라내서 상관계수 파악(-1~1)
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
import seaborn as sns
heat=sns.heatmap(df.corr(numeric_only=True), annot=True)
