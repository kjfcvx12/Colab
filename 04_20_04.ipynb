# %% [markdown]
# <a href="https://colab.research.google.com/github/kjfcvx12/Colab/blob/main/04_20_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
from torchvision import datasets
import numpy as np

from PIL import Image
import matplotlib.pyplot as plt

# %%
# 운영체제 관련기능
import os
# 파일이나 폴더 복사, 이동, 삭제
import shutil
torch.manual_seed(0)

# %%
# !pip install gdown

# %%
# !gdown 1ql4oc0aAKL3Aw7q-6XwfD_ZaK9bPh9Wl -O covid.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1ql4oc0aAKL3Aw7q-6XwfD_ZaK9bPh9Wl
# From (redirected): https://drive.google.com/uc?id=1ql4oc0aAKL3Aw7q-6XwfD_ZaK9bPh9Wl&confirm=t&uuid=4d470acd-a0de-4c9b-aa15-4ef00047a006
# To: /content/covid.zip
# 100% 1.23G/1.23G [00:10<00:00, 116MB/s]

# %%
# 현재폴더에 압축해제
# !unzip -q covid.zip -d /content/

# %%
# 압축해제 후 전체 데이터셋 폴더명을 변수에 저장함
# /content/COVID-19/train
data_dir='COVID-19 Radiography Database'
train_dir=os.path.join(data_dir,'train')
val_dir=os.path.join(data_dir,'test')

print(os.listdir(data_dir))
print(os.listdir(train_dir))
print(os.listdir(val_dir))
# Out:
# ['train', 'test']
# ['covid', 'normal', 'viral']
# ['covid', 'normal', 'viral']
